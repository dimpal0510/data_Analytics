# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline
sns.set()

# %% [markdown]
# # Line Chart

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.petal_length.plot()
# Out:
# <Axes: >

# %%
plt.show()

# %%
iris.plot()
# Out:
# <Axes: >

# %%
plt.show()

# %% [markdown]
# # Bar Plots

# %%
data = pd.Series(np.random.rand(5), index = list('abcde'))
data
# Out:
# a    0.531822
# b    0.895262
# c    0.881535
# d    0.368655
# e    0.229630
# dtype: float64

# %%
data.plot.bar(color = 'b', alpha = 1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
data.plot.barh(color = 'r', alpha = 0.5) # h is use for horizontal
# Out:
# <Axes: >

# %%
plt.show()

# %%
df = pd.DataFrame(np.random.rand(5,3),index=['one','two','three','four','five'],
                  columns = pd.Index(list('ABC')))
df.head()
# Out:
#               A         B         C
# one    0.340026  0.074247  0.472453
# two    0.059923  0.825113  0.794175
# three  0.650496  0.335153  0.391336
# four   0.438320  0.302583  0.164374
# five   0.537373  0.422726  0.704114

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
plt.show()

# %%
df.plot.barh(stacked = True,alpha = 1)
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
day_size = pd.crosstab(tips["day"],tips["size"])
day_size
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
day_size.plot.bar()
# Out:
# <Axes: xlabel='day'>

# %%
plt.show()

# %%
tips['tips_perc'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_perc
# 0       16.99  1.01  Female     No  Sun  Dinner     2   0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3   0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3   0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2   0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4   0.172069

# %%
sns.barplot(x = 'day', y = 'tips_perc', data = tips, orient = 'v')
# Out:
# <Axes: xlabel='day', ylabel='tips_perc'>

# %%
plt.show()

# %%
sns.barplot(x = 'day', y = 'tips_perc' ,hue = 'time', data = tips, orient = 'v')
# Out:
# <Axes: xlabel='day', ylabel='tips_perc'>

# %%
plt.show()

# %% [markdown]
# # Histogram and Density Plots

# %%
tips['tips_perc'].plot.hist(bins=70)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.show()

# %%
sns.histplot(tips['tips_perc'],kde=True, bins = 50, color = 'r')
# Out:
# <Axes: xlabel='tips_perc', ylabel='Count'>

# %%
plt.show()

# %% [markdown]
# # Scatter or point plots

# %%
sns.regplot(x = 'sepal_length', y = 'petal_length', data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.show()

# %%
sns.pairplot(iris)

# %%
plt.show()

# %%
sns.pairplot(iris, hue = 'species')

# %%
plt.show()

# %% [markdown]
# # Facet Grids and Categorical Data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_perc
# 0       16.99  1.01  Female     No  Sun  Dinner     2   0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3   0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3   0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2   0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4   0.172069

# %%
sns.catplot(x = 'day', y = 'tips_perc', hue = 'time', col = 'smoker', kind = 'bar', data = tips)

# %%
plt.show()

# %%
sns.catplot(x = 'day',y = 'tips_perc', row = 'time', col = 'smoker', kind = 'bar', data = tips)

# %%
plt.show()
